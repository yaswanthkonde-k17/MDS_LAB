# %% [markdown]
# <a href="https://colab.research.google.com/github/yaswanthkonde-k17/MDS_LAB/blob/main/indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# shuffle
import random

my_list = [69, 2, 3, 4, 5, 6, 7, 8, 9, 10]
print(f"Original list: {my_list}")

random.shuffle(my_list)

print(f"Shuffled list: {my_list}")
# Out:
# Original list: [69, 2, 3, 4, 5, 6, 7, 8, 9, 10]
# Shuffled list: [7, 10, 69, 4, 3, 9, 5, 8, 6, 2]

# %% [markdown]
# ### List Operations

# %% [markdown]
# indexing

# %%
list = [69,35,39,50,23]

first_element = list[0]
print(f"First element: {first_element}")

last_element = list[-1]
print(f"Last element: {last_element}")

second_element = list[1]
print(f"Second element: {second_element}")

reversed_list = list[::-1]
print(f"Reversed list (using slicing): {reversed_list}")
# Out:
# First element: 69
# Last element: 23
# Second element: 35
# Reversed list (using slicing): [23, 50, 39, 35, 69]

# %% [markdown]
# ### 2D Array Operations

# %%
l = [
    [1, 2, 3],
    [4, 69, 6],
    [7, 8, 9]
]
print(f"Our 2D Array:\n{l}")
element_69 = l[1][1]
print(f"The element at index [1][1] is: {element_69}")
another_element = l[0][2]
print(f"The element at index [0][2] is: {another_element}")
# Out:
# Our 2D Array:
# [[1, 2, 3], [4, 69, 6], [7, 8, 9]]
# The element at index [1][1] is: 69
# The element at index [0][2] is: 3

# %% [markdown]
# ### More 2D Array Indexing Operations

# %%
print(f"Current 2D Array:\n{l}")

first_row = l[0]
print(f"First row: {first_row}")

second_row = l[1]
print(f"Second row: {second_row}")

last_element_last_row = l[-1][-1]
print(f"Last element of the last row: {last_element_last_row}")

first_column = [row[0] for row in l]
print(f"First column: {first_column}")

second_column = [row[1] for row in l]
print(f"Second column: {second_column}")
# Out:
# Current 2D Array:
# [[1, 2, 3], [4, 69, 6], [7, 8, 9]]
# First row: [1, 2, 3]
# Second row: [4, 69, 6]
# Last element of the last row: 9
# First column: [1, 4, 7]
# Second column: [2, 69, 8]

# %% [markdown]
# ### Accessing Each Element of a New 2D Array

# %%
# Define the new 2D array as provided by the user
l = [
    [1, 2, 3],
    [4, 69, 6]
]

print(f"The new 2D Array:\n{l}")
print("\nAccessing each element:")

# Iterate through rows and then through elements in each row
for row_index, row in enumerate(l):
    for col_index, element in enumerate(row):
        print(f"Element at [{row_index}][{col_index}]: {element}")
# Out:
# The new 2D Array:
# [[1, 2, 3], [4, 69, 6]]
#
# Accessing each element:
# Element at [0][0]: 1
# Element at [0][1]: 2
# Element at [0][2]: 3
# Element at [1][0]: 4
# Element at [1][1]: 69
# Element at [1][2]: 6

# %% [markdown]
# ### Accessing Elements without Loops
#
# To access each element individually without using loops, you can specify the exact row and column index for each element. For a 2D array like `l = [[1, 2, 3], [4, 69, 6]]`, the elements can be accessed as follows:

# %%
print(f"The new 2D Array: {l}")

print(f"Element at [0][0]: {l[0][0]}") # Accesses the element in the first row, first column (1)
print(f"Element at [0][1]: {l[0][1]}") # Accesses the element in the first row, second column (2)
print(f"Element at [0][2]: {l[0][2]}") # Accesses the element in the first row, third column (3)
print(f"Element at [1][0]: {l[1][0]}") # Accesses the element in the second row, first column (4)
print(f"Element at [1][1]: {l[1][1]}") # Accesses the element in the second row, second column (69)
print(f"Element at [1][2]: {l[1][2]}") # Accesses the element in the second row, third column (6)
# Out:
# The new 2D Array: [[1, 2, 3], [4, 69, 6]]
# Element at [0][0]: 1
# Element at [0][1]: 2
# Element at [0][2]: 3
# Element at [1][0]: 4
# Element at [1][1]: 69
# Element at [1][2]: 6

# %% [markdown]
# ### Conditional Concatenation Reversing
#
# Let's consider two lists and a condition to select elements. We'll then concatenate the selected elements and reverse the resulting list.

# %%
# Define two example lists
list1 = [1, 2, 3, 4, 5]
list2 = [10, 11, 12, 13, 14]

print(f"Original List 1: {list1}")
print(f"Original List 2: {list2}\n")

# Define a condition: select even numbers from list1 and odd numbers from list2
# Conditional Concatenation
conditionally_selected_elements = []

for num in list1:
    if num % 2 == 0:  # If the number is even
        conditionally_selected_elements.append(num)

for num in list2:
    if num % 2 != 0:  # If the number is odd
        conditionally_selected_elements.append(num)

print(f"Conditionally concatenated list: {conditionally_selected_elements}")

# Reversing the concatenated list
reversed_concatenated_list = conditionally_selected_elements[::-1]

print(f"Reversed conditionally concatenated list: {reversed_concatenated_list}")
# Out:
# Original List 1: [1, 2, 3, 4, 5]
# Original List 2: [10, 11, 12, 13, 14]
#
# Conditionally concatenated list: [2, 4, 11, 13]
# Reversed conditionally concatenated list: [13, 11, 4, 2]
